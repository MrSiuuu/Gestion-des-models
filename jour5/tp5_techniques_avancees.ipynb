# %% [markdown]
# # TP5 - Techniques Avancées & MLOps
#
# **Master 1 Data Engineering - YNOV Montpellier**
#
# **Nom & Prénom** : ___________________
#
# **Date** : ___________________
#
# ---
#
# ## 📋 Objectif
#
# Développer un système de détection de fraude bancaire en utilisant des algorithmes avancés (SVM, KNN, XGBoost, LightGBM) et en appliquant les concepts MLOps.
